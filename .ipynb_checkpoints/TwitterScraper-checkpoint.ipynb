# %% [markdown]
# # 1. Importing required packages

# %%
from time import strftime, gmtime
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.keys import Keys

# %% [markdown]
# # 2. Inputing username and number of tweets

# %%
username = input('Input a username for searching the tweets: ')
# Out:
# Input a username for searching the tweets: nikolaevava

# %%
limit = int(input('Input the number of tweets to search for (if available): '))
# Out:
# Input the number of tweets to search for (if available): 20

# %% [markdown]
# # 3. Parsing the page and writing extracted data to table

# %%
browser = webdriver.Chrome()
url = f'https://twitter.com/{username}'
tweets_limit = limit

browser.get(url)
time.sleep(1)

body = browser.find_element_by_tag_name('body')

first_len = 0

while True:
    body.send_keys(Keys.END)
    time.sleep(1)
    tweets = browser.find_elements_by_css_selector('div.tweet')

    second_len = len(tweets)

    if second_len == first_len:
        tweets_limit = second_len
        break
    else:
        first_len = second_len

    if second_len >= tweets_limit:
        break

tweets_table = pd.DataFrame(index=range(1, tweets_limit + 1))
        
if (tweets_limit == 0):
    print('There is no tweets published by this user!')
else:

    # Extracting tweet contents
    for n in range(1, tweets_limit + 1):
        tweets_table.at[n, 'Text'] = tweets[n - 1].find_element_by_css_selector('p.tweet-text').text

        # Checking if tweet contains video or picture
        try:
            tweets[n - 1].find_element_by_css_selector('div.AdaptiveMediaOuterContainer')
            tweets_table.at[n, 'Mediafile'] = 'Yes'
        except NoSuchElementException:
            tweets_table.at[n, 'Mediafile'] = 'No'

        # Checking if tweet contains another tweet quotation
        try:
            tweets[n - 1].find_element_by_css_selector('div.QuoteTweet-container')
            tweets_table.at[n, 'Tweet quotation'] = 'Yes'
        except NoSuchElementException:
            tweets_table.at[n, 'Tweet quotation'] = 'No'

        likes = tweets[n - 1].find_element_by_css_selector('button.ProfileTweet-action--unfavorite span.ProfileTweet-actionCount').text
        if likes == '':
            try:
                tweets[n - 1].find_element_by_css_selector('ProfileTweet-actionCount ProfileTweet-actionCount--isZero')
                tweets_table.at[n, 'Likes'] = 
            except NoSuchElementException:
                tweets_table.at[n, 'Likes'] = 'sdfsfsdf'
        else:
            tweets_table.at[n, 'Likes'] = int(likes)
        
    
    # Date and Time
    stamps = browser.find_elements_by_css_selector('div.tweet span._timestamp')[:tweets_limit]
    tweets_table.insert(column='Date & Time', loc=0, value=[strftime('%d %b %Y %H:%M', gmtime(int(stamp.get_attribute('data-time')))) for stamp in stamps])

    # Author of the tweet
    authors = browser.find_elements_by_css_selector('div.tweet strong.fullname')[:tweets_limit]
    tweets_table.insert(column='Author', loc=1, value=[author.text for author in authors])

    # Twitter account link with '@' 
    usernames = browser.find_elements_by_css_selector('div.tweet a.js-action-profile span.username b')[:tweets_limit]
    tweets_table.insert(column='Twitter user', loc=2, value=[f'@{username.text}' for username in usernames])    

    # Number of Likes, Retweets and Comments
#    likes = browser.find_elements_by_css_selector('div.tweet button.ProfileTweet-action--unfavorite span.ProfileTweet-actionCount')[:tweets_limit]
#    tweets_table.insert(column='Likes', loc=3, value=[like.get_attribute('data-tweet-stat-count') for like in likes])
    retweets = browser.find_elements_by_css_selector('div.tweet button.ProfileTweet-actionButton.js-actionRetweet span.ProfileTweet-actionCount')[:tweets_limit]
    tweets_table.insert(column='Retweets', loc=4, value=[retweet.get_attribute('data-tweet-stat-count') for retweet in retweets])
    comments = browser.find_elements_by_css_selector('div.tweet span.ProfileTweet-action--reply span.ProfileTweet-actionCount')[:tweets_limit]
    tweets_table.insert(column='Comments', loc=5, value=[comment.get_attribute('data-tweet-stat-count') for comment in comments])
     
    with pd.option_context('display.max_rows', None, 'display.max_columns', None):
        display(tweets_table)

browser.close()
# Out:
#           Date & Time           Author  Twitter user  \
# 1   26 Feb 2018 14:30  мєх на капішоні  @nikolaevava
# 2   29 Dec 2018 09:20  мєх на капішоні  @nikolaevava
# 3   28 Dec 2018 11:13  мєх на капішоні  @nikolaevava
# 4   27 Dec 2018 11:39  мєх на капішоні  @nikolaevava
# 5   25 Dec 2018 11:04  мєх на капішоні  @nikolaevava
# 6   25 Dec 2018 08:34  мєх на капішоні  @nikolaevava
# 7   23 Dec 2018 19:14  мєх на капішоні  @nikolaevava
# 8   21 Dec 2018 16:05  мєх на капішоні  @nikolaevava
# 9   15 Dec 2018 22:28  мєх на капішоні  @nikolaevava
# 10  14 Dec 2018 12:47  мєх на капішоні  @nikolaevava
# 11  11 Dec 2018 16:46  мєх на капішоні  @nikolaevava
# 12  11 Dec 2018 08:00  мєх на капішоні  @nikolaevava
# 13  09 Dec 2018 13:51  мєх на капішоні  @nikolaevava
# 14  07 Dec 2018 19:44  мєх на капішоні  @nikolaevava
# 15  06 Dec 2018 09:42  мєх на капішоні  @nikolaevava
# 16  06 Dec 2018 09:34  мєх на капішоні  @nikolaevava
# 17  01 Dec 2018 14:11  мєх на капішоні  @nikolaevava
# 18  30 Nov 2018 11:32  мєх на капішоні  @nikolaevava
# 19  26 Nov 2018 06:00  мєх на капішоні  @nikolaevava
# 20  25 Nov 2018 19:25  мєх на капішоні  @nikolaevava
#
#                                                  Text Retweets Comments  \
# 1   есть такая теория, шо чем смешнее твитор, тем ...     None        2
# 2   приключения начинаются: рейс задержали на СЕМЬ...     None        2
# 3   собака как-то прознала, что мы уезжаем завтра ...     None        1
# 4   помните твит про аллергию на креветки. дополня...     None        1
# 5   как в домашних условиях узнать, шо твой чумода...     None        4
# 6   дома щакончились носовые платки. скоро начну с...     None        0
# 7   у меня аллергия на креветки. все. официально м...     None        2
# 8   мой типичный вечер: купить лекарство в аптеке....     None        0
# 9   новая рубрика #рецензияводнослово\nЛарс фон Тр...     None        0
# 10                                    опять актуально     None        0
# 11  на районе есть точка торгашей апельсинами-гран...     None        0
# 12                                            але-оп!     None        0
# 13  впервые попала на контролера в берлинском трам...     None        0
# 14  дома нет инета, включила в кои то веки колонки...     None        2
# 15                         хто не поняв — это Берхайн     None        0
# 16  нормальное расписание тусы. НЕ ТО ШО В ЭТАМ ВА...     None        1
# 17                           помедленней, я записываю     None        0
# 18  сходила подстричься — придумала идею для старт...     None        1
# 19  какие-то адские флешбеки в 2014: просыпаешься ...     None        0
# 20                              бля, что происходит?!     None        0
#
#    Mediafile Tweet quotation Likes
# 1         No              No
# 2         No              No
# 3         No              No
# 4         No              No
# 5         No              No
# 6         No              No
# 7         No              No
# 8         No              No
# 9         No              No
# 10        No             Yes
# 11        No              No
# 12       Yes              No
# 13        No              No
# 14        No              No
# 15        No              No
# 16       Yes              No
# 17       Yes              No
# 18        No              No
# 19        No              No
# 20        No              No

# %%
tweets_table.to_csv('test.csv')
